# %%
import pandas as pd
import numpy as np
from scipy.linalg import norm, eigh
import plotly_express as px
from gensim.models import word2vec
from gensim.corpora import Dictionary
from sklearn.manifold import TSNE as tsne

# %%
import gensim
gensim.__version__
# Out:
# '4.3.0'

# %%
OHCO = ['doc_source', 'doc_id', 'sent_num', 'token_num']

# %%
LIB = pd.read_csv('LIB.csv').set_index('doc_id')
LIB['doc_date'] = pd.to_datetime(LIB['doc_date'])
CORPUS = pd.read_csv('CORPUS.csv').set_index(OHCO)
VOCAB = pd.read_csv('VOCAB.csv').set_index('term_str')
VOCAB.index = VOCAB.index.astype(str)
BOW = pd.read_csv('BOW.csv').set_index(['doc_source', 'term_str'])

# %%
BAG=OHCO[:2]

# %%
# word2vec parameters
w2v_params = dict(
    window = 2,
    vector_size = 256,
    min_count = 50, # THIS LIMITS OUR VOCAB
    workers = 4
)

# %%
docs = CORPUS[~CORPUS.pos.str.match('NNPS?')].dropna(subset=['term_str'])\
    .groupby(BAG)\
    .term_str.apply(lambda  x:  x.tolist())\
    .reset_index()['term_str'].tolist()
docs = [doc for doc in docs if len(doc) > 1] # Lose single word docs

# %%
vocab = Dictionary(docs)

# %%
model = word2vec.Word2Vec(docs, **w2v_params)

# %%
model.wv.vectors
# Out:
# array([[-0.1957403 ,  0.04607484,  0.12868099, ..., -0.3713121 ,
#         -0.43647534, -0.3311079 ],
#        [-0.23684417,  0.4581675 ,  0.03001502, ..., -0.73305607,
#         -0.76463586,  0.21777257],
#        [-0.8490012 , -1.1386752 , -0.09555919, ...,  0.53252965,
#         -0.51346904,  0.8004266 ],
#        ...,
#        [ 0.06058296, -0.15441361, -0.12034663, ..., -0.19362028,
#         -0.17303187, -0.11026042],
#        [ 0.02019604, -0.14915517, -0.01521353, ..., -0.11712921,
#         -0.14330223, -0.0254339 ],
#        [ 0.01651932, -0.09659509,  0.11444028, ...,  0.01298062,
#         -0.09673145, -0.09051858]], dtype=float32)

# %%
def get_vector(row):
    w = row.name
    try:
        vec = model.wv[w]
    except KeyError as e:
        vec = None
    return vec

# %%
VOCAB_W2V = pd.DataFrame(VOCAB.apply(get_vector, axis=1).dropna()).apply(lambda x: pd.Series(x[0]), axis=1)

# %%
VOCAB_W2V
# Out:
#                0         1         2         3         4         5    \
# term_str
# 0         0.098821 -0.113353 -0.113406  0.220672  0.066275 -0.006576
# 00        0.114244 -0.125504 -0.214608  0.228109  0.099511  0.131072
# 1         0.217804  0.232361 -0.447131  0.349515  0.107387  0.094228
# 10        0.056745  0.036093 -0.400287 -0.091649  0.013360  0.080617
# 100       0.175715  0.150928 -0.195283 -0.331427  0.221295 -0.039749
# ...            ...       ...       ...       ...       ...       ...
# your     -0.712526 -0.633957  0.195404  0.554289  0.203902 -0.346959
# youre    -0.115910 -0.203884  0.110471  0.218355  0.095779 -0.091469
# youth     0.055947 -0.055231  0.014401  0.063446  0.025162 -0.021855
# zero     -0.007965 -0.113030 -0.059136  0.108850  0.018280 -0.094054
# zone      0.025953 -0.032972 -0.078297  0.025580  0.025326  0.015171
#
#                6         7         8         9    ...       246       247  \
# term_str                                          ...
# 0         0.075603  0.053665 -0.288604 -0.026132  ...  0.230262  0.159708
# 00        0.253737  0.137933 -0.174644 -0.023469  ...  0.199091  0.255560
# 1        -0.189284 -0.234606 -0.360988  0.248755  ...  0.247217  0.169631
# 10       -0.027337 -0.342160 -0.194205  0.388350  ...  0.187492  0.344382
# 100       0.020659 -0.249552 -0.241445  0.272590  ...  0.180043  0.423658
# ...            ...       ...       ...       ...  ...       ...       ...
# your      0.277659 -0.134012 -0.590113  0.334255  ...  0.273868  0.205379
# youre    -0.228876  0.316751 -0.561028  0.442568  ...  0.323261 -0.207181
# youth     0.136325 -0.029158 -0.019111 -0.004432  ...  0.104181  0.049966
# zero      0.017918  0.034945 -0.142309  0.044779  ...  0.099797  0.074769
# zone     -0.021436  0.019465  0.009179 -0.022263  ...  0.120006  0.067145
#
#                248       249       250       251       252       253  \
# term_str
# 0         0.117928 -0.153342 -0.384019  0.150273 -0.324415 -0.554108
# 00        0.137251 -0.222590 -0.476479  0.067703 -0.218179 -0.857192
# 1         0.100059 -0.413860 -0.432601  0.107500 -0.188955 -0.465658
# 10       -0.003838  0.219423 -0.324690  0.129130 -0.364755 -0.601746
# 100       0.079147  0.309146 -0.342984  0.048027 -0.389757 -0.491092
# ...            ...       ...       ...       ...       ...       ...
# your      0.097578 -0.345420 -0.412060  0.591902 -0.959354 -0.140821
# youre    -0.238223  0.223361 -0.205367  0.209849 -0.519526  0.203070
# youth    -0.052212 -0.031604 -0.136271  0.025389 -0.018851 -0.090872
# zero     -0.020580 -0.065395 -0.194935  0.119530 -0.229075 -0.162464
# zone     -0.043165 -0.068355 -0.064224  0.065050 -0.089141 -0.057009
#
#                254       255
# term_str
# 0        -0.253431 -0.076723
# 00       -0.382382 -0.221669
# 1        -0.101958 -0.280319
# 10       -0.209323 -0.408586
# 100      -0.147920 -0.416151
# ...            ...       ...
# your     -0.134387  0.610200
# youre    -0.019770  0.252856
# youth    -0.055213  0.030433
# zero     -0.110558 -0.006112
# zone     -0.084338 -0.026610
#
# [3043 rows x 256 columns]

# %%
tsne_engine = tsne(perplexity=40, n_components=2, init='pca', n_iter=2500, random_state=23)

# %%
tsne_model = tsne_engine.fit_transform(VOCAB_W2V.to_numpy())

# %%
TSNE = pd.DataFrame(tsne_model, columns=['x','y'], index=VOCAB_W2V.index)

# %%
X = TSNE.join(VOCAB, how='left')

# %%
vis1=px.scatter(X.reset_index(), 'x', 'y', 
           text='term_str', 
           hover_name='term_str',
           height=1000).update_traces(
                mode='markers+text', 
                textfont=dict(color='black', size=14, family='Arial'),
                textposition='top center')

# %%
vis1
# Out:
# <div>                            <div id="acf013ce-6a3d-4032-9f44-95b81c4fbc8b" class="plotly-graph-div" style="height:1000px; width:100%;"></div>            <script type="text/javascript">                require(["plotly"], function(Plotly) {                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("acf013ce-6a3d-4032-9f44-95b81c4fbc8b")) {                    Plotly.newPlot(                        "acf013ce-6a3d-4032-9f44-95b81c4fbc8b",                        [{"hovertemplate":"<b>%{hovertext}</b><br><br>x=%{x}<br>y=%{y}<br>term_str=%{text}<extra></extra>","hovertext":["0","00","1","10","100","1000","100000","10th","11","11th","12","12th","13","13th","13yearold","14","14th","14yearold","15","150","15th","15yearold","16","16th","16yearold","17","17th","17yearold","18","18th","19","19th","1st","2","20","200","2000","200000","2008","2009","2010","2011","2012","2013","2014","2015","2016","2017","2018","2019","2020","20th","21","21st","22","23","24","25","26","27","28","29","2nd","2q","2yearold","3","30","300","31","32","33","34","35","36","3q","3rd","3yearold","4","40","400","42","43","45","48","49ers","4th","5","50","500","51","52","55","5th","6","60","62","63","64","65","6th","7","70","737","75","7th","8","80","8th","9","90","911","9th","a","ab","abandoned","ability","able","aboard","abortion","abortions","about","above","absolutely","abuse","abused","academic","accept","access","accident","accidentally","according","account","accounts","accusations","accused","accuses","accusing","across","act","acting","action","actions","active","activist","activists","activities","activity","actor","actress","acts","actual","actually","ad","add","added","adding","addition","additional","address","adds","administration","administrations","administrative","admitted","ads","adult","adults","advance","advanced","advantage","advertise","advice","adviser","advisers","advocates","affair","affect","affected","african","africanamerican","after","afternoon","again","against","age","agencies","agency","agenda","agent","agents","aggressive","ago","agree","agreed","agreement","ahead","aid","aide","aides","aim","aimed","aims","air","aircraft","airline","airport","album","alert","alive","all","allegations","alleged","allegedly","alleging","alliance","allies","allow","allowed","allowing","allows","ally","almost","alone","along","already","also","alternative","although","always","am","ambassador","american","amid","among","amount","an","analysis","ancient","and","anger","angry","animal","animals","anniversary","announce","announced","announcement","announces","announcing","annual","another","answer","answers","anthem","antisemitic","antitrump","any","anyone","anything","anyway","apart","apartment","apologized","app","apparent","apparently","appeal","appeals","appear","appearance","appeared","appearing","appears","apply","appointed","appointment","approach","approval","approve","approved","are","area","areas","arent","argued","argument","arguments","armed","arms","army","around","arrest","arrested","arrests","arrived","art","article","articles","artist","as","asian","aside","ask","asked","asking","asks","assault","assaulted","assaulting","assistance","assistant","associate","associated","associates","asylum","at","attack","attacked","attacking","attacks","attempt","attempted","attempting","attempts","attend","attended","attending","attention","attorney","attorneys","audience","australian","author","authorities","authority","available","average","avoid","award","awarded","aware","away","baby","back","backed","background","backing","backlash","bad","badly","bail","ballistic","ballot","ballots","ban","bank","banks","banned","banning","bans","bar","barely","bars","base","baseball","based","basic","basis","basketball","bathroom","battle","battling","be","beach","bear","beat","beating","became","because","become","becomes","becoming","been","before","began","begin","beginning","begins","begun","beha ...

# %%
VOCAB_W2V.to_csv('VOCAB_W2V.csv')

# %%
import kaleido

# %%
vis1.write_image('tsne.png')
